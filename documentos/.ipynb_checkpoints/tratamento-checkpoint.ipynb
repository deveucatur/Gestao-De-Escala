# %%
import pandas as pd
import json

planil = pd.read_excel('ProjetoHorários.xlsx', sheet_name='Projeto')

cod_linhas_ex = list(set([x for x in list(planil['Projeto - Horários']) if str(x).strip() not in ('Cód Linha', 'nan')]))

dic_dados = {}
for lin in cod_linhas_ex:
    idx_planil = [x for x in list(planil['Projeto - Horários'])].index(lin)
    
    aux1 = {'LINHA': list(planil['Unnamed: 2'])[idx_planil],
            'HORÁRIO INÍCIO': str(list(planil['Unnamed: 1'])[idx_planil])}
    
    #DESCOBRINDO OS SENTIDOS DA LINHAS(SE TEM IDA E VOLTA)
    sentidos_by_lin = list(set([planil['Unnamed: 12'][idx_lin] for idx_lin in range(len(list(planil['Projeto - Horários']))) if planil['Projeto - Horários'][idx_lin] == lin]))
    
    #DADOS SOMENTE DAQUELE SENTIDO
    aux2 = {}
    for sentid in sentidos_by_lin:
        aux3 = {}
        for x in range(len(planil['Projeto - Horários'])):
            if planil['Unnamed: 12'][x] == sentid:
                if planil['Projeto - Horários'][x] == lin:
                    aux3[planil['Unnamed: 3'][x]] = {
                            'SECCIONAMENTO': planil['Unnamed: 4'][x], 
                            'HORÁRIO CHEGADA': str(planil['Unnamed: 5'][x]),
                            'TEMPO DE PARADA': str(planil['Unnamed: 7'][x]),
                            'HORÁRIO SAIDA': str(planil['Unnamed: 9'][x])
                           }

                    aux2[sentid] = aux3
    aux1['PERCURSO'] = aux2

    dic_dados[lin] = aux1
    
    
with open('projeto_linhas_horarios.json', 'w') as arquivo_json:
    json.dump(dic_dados, arquivo_json, indent=4)
# Out:
# {'00280': {'LINHA': 'Costa Marques x Cacoal',
#   'HORÁRIO INÍCIO': '08:02:00',
#   'PERCURSO': {'Volta': {'0104': {'SECCIONAMENTO': 'Linha E',
#      'HORÁRIO CHEGADA': '16:07:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:07:00'}}}},
#  'D1': {'LINHA': 'Vilhena x Porto Velho',
#   'HORÁRIO INÍCIO': '07:35:00',
#   'PERCURSO': {'Volta': {'0351': {'SECCIONAMENTO': 'Vilhena Garagem',
#      'HORÁRIO CHEGADA': '2024-04-16 07:00:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-16 07:15:00'},
#     '0820': {'SECCIONAMENTO': 'Vilhena',
#      'HORÁRIO CHEGADA': '2024-04-16 07:20:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-16 07:35:00'},
#     '0821': {'SECCIONAMENTO': 'Pimenta Bueno',
#      'HORÁRIO CHEGADA': '2024-04-16 10:05:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-16 10:20:00'},
#     '0822': {'SECCIONAMENTO': 'Cacoal',
#      'HORÁRIO CHEGADA': '2024-04-16 11:10:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-16 11:40:00'},
#     '0823': {'SECCIONAMENTO': 'Presidente Medici',
#      'HORÁRIO CHEGADA': '2024-04-16 12:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 12:50:00'},
#     '0962': {'SECCIONAMENTO': 'Ji-Paraná',
#      'HORÁRIO CHEGADA': '2024-04-16 13:30:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-16 13:45:00'},
#     '0235': {'SECCIONAMENTO': 'Ouro Preto Rodoviária',
#      'HORÁRIO CHEGADA': '2024-04-16 14:30:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 14:40:00'},
#     '0824': {'SECCIONAMENTO': 'Jarú',
#      'HORÁRIO CHEGADA': '2024-04-16 15:25:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:35:00'},
#     '0233': {'SECCIONAMENTO': 'Ariquemes',
#      'HORÁRIO CHEGADA': '2024-04-16 16:55:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-16 17:15:00'},
#     '0234': {'SECCIONAMENTO': 'Porto Velho',
#      'HORÁRIO CHEGADA': '2024-04-16 20:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 20:10:00'},
#     '9075': {'SECCIONAMENTO': 'Porto Velho Garagem',
#      'HORÁRIO CHEGADA': '2024-04-16 20:20:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-16 20:20:00'}}}},
#  'D46': {'LINHA': 'Cerejeiras x Porto Velho',
#   'HORÁRIO INÍCIO': '10:00:00',
#   'PERCURSO': {'Ida': {'9075': {'SECCIONAMENTO': 'Porto Velho Garagem',
#      'HORÁRIO CHEGADA': '2024-04-23 21:20:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-23 21:20:00'},
#     '0234': {'SECCIONAMENTO': 'Porto Velho',
#      'HORÁRIO CHEGADA': '2024-04-23 21:30:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-23 22:00:00'},
#     '0233': {'SECCIONAMENTO': 'Ariquemes',
#      'HORÁRIO CHEGADA': '2024-04-24 00:40:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-24 00:50:00'},
#     '0824': {'SECCIONAMENTO': 'Jarú',
#      'HORÁRIO CHEGADA': '2024-04-24 02:10:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-24 02:15:00'},
#     '0235': {'SECCIONAMENTO': 'Ouro Preto Rodoviária',
#      'HORÁRIO CHEGADA': '2024-04-23 23:05:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-23 23:15:00'},
#     '0962': {'SECCIONAMENTO': 'Ji-Paraná',
#      'HORÁRIO CHEGADA': '2024-04-24 03:30:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-24 03:40:00'},
#     '0823': {'SECCIONAMENTO': 'Presidente Medici',
#      'HORÁRIO CHEGADA': '2024-04-24 04:15:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-24 04:25:00'},
#     '0822': {'SECCIONAMENTO': 'Cacoal',
#      'HORÁRIO CHEGADA': '2024-04-24 05:20:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-24 05:30:00'},
#     '0821': {'SECCIONAMENTO': 'Pimenta Bueno',
#      'HORÁRIO CHEGADA': '2024-04-24 06:05:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-24 06:15:00'},
#     '5027': {'SECCIONAMENTO': 'Fazenda Guaporé',
#      'HORÁRIO CHEGADA': '2024-04-25 13:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-25 13:50:00'},
#     '0820': {'SECCIONAMENTO': 'Vilhena',
#      'HORÁRIO CHEGADA': '2024-04-24 08:45:00',
#      'TEMPO DE PARADA': '00:50:00',
#      'HORÁRIO SAIDA': '2024-04-24 09:35:00'},
#     '1320': {'SECCIONAMENTO': 'Entroncamento Ro/399',
#      'HORÁRIO CHEGADA': '2024-04-25 17:30:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-25 17:30:00'},
#     '0200': {'SECCIONAMENTO': 'Serra',
#      'HORÁRIO CHEGADA': '2024-04-25 17:40:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-25 17:40:00'},
#     '0002': {'SECCIONAMENTO': 'Cota',
#      'HORÁRIO CHEGADA': '2024-04-25 17:50:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-25 17:50:00'},
#     '0202': {'SECCIONAMENTO': 'Pires',
#      'HORÁRIO CHEGADA': '2024-04-25 18:00:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-25 18:00:00'},
#     '0172': {'SECCIONAMENTO': 'Colorado Do Oeste',
#      'HORÁRIO CHEGADA': '2024-04-24 10:55:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-24 11:05:00'},
#     '1573': {'SECCIONAMENTO': 'Km 10 - Cerejeiras',
#      'HORÁRIO CHEGADA': '2024-04-25 18:55:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-25 18:55:00'},
#     '1190': {'SECCIONAMENTO': 'Km 15 - Cerejeiras',
#      'HORÁRIO CHEGADA': '2024-04-25 19:05:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-25 19:05:00'},
#     '0091': {'SECCIONAMENTO': 'Km 30 - Cerejeiras',
#      'HORÁRIO CHEGADA': '2024-04-25 19:15:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-25 19:15:00'},
#     '1166': {'SECCIONAMENTO': 'Cerejeiras',
#      'HORÁRIO CHEGADA': '2024-04-24 11:40:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-24 11:50:00'},
#     '1566': {'SECCIONAMENTO': 'Cerejeiras - Garagem',
#      'HORÁRIO CHEGADA': '2024-04-24 11:55:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-24 11:55:00'},
#     '0402': {'SECCIONAMENTO': 'Itapuã Do Oeste',
#      'HORÁRIO CHEGADA': '2024-04-23 18:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-23 18:55:00'}},
#    'Volta': {'1566': {'SECCIONAMENTO': 'Cerejeiras - Garagem',
#      'HORÁRIO CHEGADA': '17:10:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '17:10:00'},
#     '1166': {'SECCIONAMENTO': 'Cerejeiras',
#      'HORÁRIO CHEGADA': '17:15:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '17:30:00'},
#     '0091': {'SECCIONAMENTO': 'Km 30 - Cerejeiras',
#      'HORÁRIO CHEGADA': '10:11:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '10:11:00'},
#     '1190': {'SECCIONAMENTO': 'Km 15 - Cerejeiras',
#      'HORÁRIO CHEGADA': '10:15:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '10:15:00'},
#     '1573': {'SECCIONAMENTO': 'Km 10 - Cerejeiras',
#      'HORÁRIO CHEGADA': '10:20:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '10:20:00'},
#     '0172': {'SECCIONAMENTO': 'Colorado Do Oeste',
#      'HORÁRIO CHEGADA': '18:05:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '18:15:00'},
#     '0202': {'SECCIONAMENTO': 'Pires',
#      'HORÁRIO CHEGADA': '10:45:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '10:45:00'},
#     '0002': {'SECCIONAMENTO': 'Cota',
#      'HORÁRIO CHEGADA': '10:55:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '10:55:00'},
#     '0200': {'SECCIONAMENTO': 'Serra',
#      'HORÁRIO CHEGADA': '11:05:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '11:05:00'},
#     '1320': {'SECCIONAMENTO': 'Entroncamento Ro/399',
#      'HORÁRIO CHEGADA': '11:15:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '11:15:00'},
#     '0820': {'SECCIONAMENTO': 'Vilhena',
#      'HORÁRIO CHEGADA': '19:35:00',
#      'TEMPO DE PARADA': '00:50:00',
#      'HORÁRIO SAIDA': '20:25:00'},
#     '0821': {'SECCIONAMENTO': 'Pimenta Bueno',
#      'HORÁRIO CHEGADA': '22:50:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '23:00:00'},
#     '0822': {'SECCIONAMENTO': 'Cacoal',
#      'HORÁRIO CHEGADA': '23:50:00',
#      'TEMPO DE PARADA': '1899-12-29 00:15:00',
#      'HORÁRIO SAIDA': '00:05:00'},
#     '0823': {'SECCIONAMENTO': 'Presidente Medici',
#      'HORÁRIO CHEGADA': '00:55:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '01:00:00'},
#     '0962': {'SECCIONAMENTO': 'Ji-Paraná',
#      'HORÁRIO CHEGADA': '01:35:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '01:45:00'},
#     '0235': {'SECCIONAMENTO': 'Ouro Preto Rodoviária',
#      'HORÁRIO CHEGADA': '00:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '00:25:00'},
#     '0824': {'SECCIONAMENTO': 'Jarú',
#      'HORÁRIO CHEGADA': '02:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '02:50:00'},
#     '0233': {'SECCIONAMENTO': 'Ariquemes',
#      'HORÁRIO CHEGADA': '04:10:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '04:20:00'},
#     '0234': {'SECCIONAMENTO': 'Porto Velho',
#      'HORÁRIO CHEGADA': '07:15:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '07:25:00'},
#     '9075': {'SECCIONAMENTO': 'Porto Velho Garagem',
#      'HORÁRIO CHEGADA': '07:35:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '07:35:00'},
#     '5027': {'SECCIONAMENTO': 'Fazenda Guaporé',
#      'HORÁRIO CHEGADA': '18:40:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '18:45:00'},
#     '9760': {'SECCIONAMENTO': 'Hospital Sta Marcelina- Pvho',
#      'HORÁRIO CHEGADA': '05:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '05:25:00'}}}},
#  '09319': {'LINHA': 'Cascavel x Porto Velho',
#   'HORÁRIO INÍCIO': '09:50:00',
#   'PERCURSO': {'Ida': {'1204': {'SECCIONAMENTO': 'Cascavel  Garagem',
#      'HORÁRIO CHEGADA': '08:25:00',
#      'TEMPO DE PARADA': '01:00:00',
#      'HORÁRIO SAIDA': '09:25:00'},
#     '0208': {'SECCIONAMENTO': 'Cascavel',
#      'HORÁRIO CHEGADA': '09:30:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '09:50:00'},
#     '0218': {'SECCIONAMENTO': 'Toledo',
#      'HORÁRIO CHEGADA': '10:40:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '10:45:00'},
#     '4041': {'SECCIONAMENTO': 'Marechal C Rondon',
#      'HORÁRIO CHEGADA': '11:30:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '11:35:00'},
#     '1888': {'SECCIONAMENTO': 'Palotina - 4041',
#      'HORÁRIO CHEGADA': '11:36:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '11:36:00'},
#     '0314': {'SECCIONAMENTO': 'Guaíra',
#      'HORÁRIO CHEGADA': '12:35:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '12:40:00'},
#     '0773': {'SECCIONAMENTO': 'Mundo Novo',
#      'HORÁRIO CHEGADA': '12:30:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '12:35:00'},
#     '0774': {'SECCIONAMENTO': 'Eldorado',
#      'HORÁRIO CHEGADA': '13:05:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '13:35:00'},
#     '0770': {'SECCIONAMENTO': 'Naviraí',
#      'HORÁRIO CHEGADA': '14:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '14:50:00'},
#     '0726': {'SECCIONAMENTO': 'Dourados',
#      'HORÁRIO CHEGADA': '17:00:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '17:10:00'},
#     '0986': {'SECCIONAMENTO': 'Dourados P. De Apoio',
#      'HORÁRIO CHEGADA': '17:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '17:25:00'},
#     '0533': {'SECCIONAMENTO': 'Rio Brilhante',
#      'HORÁRIO CHEGADA': '18:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '18:25:00'},
#     '0783': {'SECCIONAMENTO': 'Nova Alvorada Do Sul',
#      'HORÁRIO CHEGADA': '19:05:00',
#      'TEMPO DE PARADA': '00:40:00',
#      'HORÁRIO SAIDA': '19:45:00'},
#     '0771': {'SECCIONAMENTO': 'Campo Grande',
#      'HORÁRIO CHEGADA': '21:15:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '21:35:00'},
#     '0782': {'SECCIONAMENTO': 'Campo Grande Pa',
#      'HORÁRIO CHEGADA': '21:45:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '22:05:00'},
#     '0772': {'SECCIONAMENTO': 'São Gabriel Do Oeste',
#      'HORÁRIO CHEGADA': '00:04:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '00:05:00'},
#     '1335': {'SECCIONAMENTO': 'Restaurante Talismã',
#      'HORÁRIO CHEGADA': '01:25:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '01:45:00'},
#     '0767': {'SECCIONAMENTO': 'Coxim',
#      'HORÁRIO CHEGADA': '01:55:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '02:00:00'},
#     '0350': {'SECCIONAMENTO': 'Rondonópolis',
#      'HORÁRIO CHEGADA': '05:00:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '05:05:00'},
#     '0461': {'SECCIONAMENTO': 'Jaciara',
#      'HORÁRIO CHEGADA': '06:04:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '06:05:00'},
#     '0346': {'SECCIONAMENTO': 'Cuiabá',
#      'HORÁRIO CHEGADA': '08:15:00',
#      'TEMPO DE PARADA': '00:50:00',
#      'HORÁRIO SAIDA': '09:05:00'},
#     '0349': {'SECCIONAMENTO': 'Cáceres',
#      'HORÁRIO CHEGADA': '12:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '12:10:00'},
#     '0582': {'SECCIONAMENTO': 'Entroncamento Mirassol',
#      'HORÁRIO CHEGADA': '13:10:00',
#      'TEMPO DE PARADA': '00:40:00',
#      'HORÁRIO SAIDA': '13:50:00'},
#     '0348': {'SECCIONAMENTO': 'Pontes E Lacerda',
#      'HORÁRIO CHEGADA': '15:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '15:55:00'},
#     '0474': {'SECCIONAMENTO': 'Comodoro',
#      'HORÁRIO CHEGADA': '18:25:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '18:45:00'},
#     '0820': {'SECCIONAMENTO': 'Vilhena',
#      'HORÁRIO CHEGADA': '20:20:00',
#      'TEMPO DE PARADA': '01:00:00',
#      'HORÁRIO SAIDA': '21:20:00'},
#     '0821': {'SECCIONAMENTO': 'Pimenta Bueno',
#      'HORÁRIO CHEGADA': '23:55:00',
#      'TEMPO DE PARADA': '1899-12-29 00:10:00',
#      'HORÁRIO SAIDA': '00:05:00'},
#     '0822': {'SECCIONAMENTO': 'Cacoal',
#      'HORÁRIO CHEGADA': '00:55:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '01:10:00'},
#     '0823': {'SECCIONAMENTO': 'Presidente Medici',
#      'HORÁRIO CHEGADA': '02:10:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '02:15:00'},
#     '0962': {'SECCIONAMENTO': 'Ji-Paraná',
#      'HORÁRIO CHEGADA': '02:50:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '03:05:00'},
#     '5549': {'SECCIONAMENTO': 'Ouro Preto',
#      'HORÁRIO CHEGADA': '03:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '03:50:00'},
#     '0824': {'SECCIONAMENTO': 'Jarú',
#      'HORÁRIO CHEGADA': '04:40:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '04:45:00'},
#     '0233': {'SECCIONAMENTO': 'Ariquemes',
#      'HORÁRIO CHEGADA': '05:55:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '06:15:00'},
#     '0234': {'SECCIONAMENTO': 'Porto Velho',
#      'HORÁRIO CHEGADA': '09:15:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '09:35:00'},
#     '9075': {'SECCIONAMENTO': 'Porto Velho Garagem',
#      'HORÁRIO CHEGADA': '09:50:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '09:50:00'}},
#    'Volta': {'9075': {'SECCIONAMENTO': 'Porto Velho Garagem',
#      'HORÁRIO CHEGADA': '2024-04-15 15:00:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-15 15:15:00'},
#     '0234': {'SECCIONAMENTO': 'Porto Velho',
#      'HORÁRIO CHEGADA': '2024-04-15 15:30:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-15 16:00:00'},
#     '0233': {'SECCIONAMENTO': 'Ariquemes',
#      'HORÁRIO CHEGADA': '2024-04-15 18:50:00',
#      'TEMPO DE PARADA': '00:40:00',
#      'HORÁRIO SAIDA': '2024-04-15 19:30:00'},
#     '0824': {'SECCIONAMENTO': 'Jarú',
#      'HORÁRIO CHEGADA': '2024-04-15 20:40:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 20:45:00'},
#     '5549': {'SECCIONAMENTO': 'Ouro Preto',
#      'HORÁRIO CHEGADA': '2024-04-15 21:30:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 21:40:00'},
#     '0962': {'SECCIONAMENTO': 'Ji-Paraná',
#      'HORÁRIO CHEGADA': '2024-04-15 22:20:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-15 22:35:00'},
#     '0823': {'SECCIONAMENTO': 'Presidente Medici',
#      'HORÁRIO CHEGADA': '2024-04-15 23:15:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 23:20:00'},
#     '0822': {'SECCIONAMENTO': 'Cacoal',
#      'HORÁRIO CHEGADA': '2024-04-16 00:20:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-16 00:35:00'},
#     '0821': {'SECCIONAMENTO': 'Pimenta Bueno',
#      'HORÁRIO CHEGADA': '2024-04-16 01:25:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 01:30:00'},
#     '0820': {'SECCIONAMENTO': 'Vilhena',
#      'HORÁRIO CHEGADA': '2024-04-16 04:20:00',
#      'TEMPO DE PARADA': '00:50:00',
#      'HORÁRIO SAIDA': '2024-04-16 05:10:00'},
#     '0474': {'SECCIONAMENTO': 'Comodoro',
#      'HORÁRIO CHEGADA': '2024-04-16 06:45:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-16 07:05:00'},
#     '0348': {'SECCIONAMENTO': 'Pontes E Lacerda',
#      'HORÁRIO CHEGADA': '2024-04-16 09:35:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 09:45:00'},
#     '0582': {'SECCIONAMENTO': 'Entroncamento Mirassol',
#      'HORÁRIO CHEGADA': '2024-04-16 11:45:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-16 12:15:00'},
#     '0349': {'SECCIONAMENTO': 'Cáceres',
#      'HORÁRIO CHEGADA': '2024-04-16 13:20:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 13:30:00'},
#     '0346': {'SECCIONAMENTO': 'Cuiabá',
#      'HORÁRIO CHEGADA': '2024-04-16 17:00:00',
#      'TEMPO DE PARADA': '01:00:00',
#      'HORÁRIO SAIDA': '2024-04-16 18:00:00'},
#     '1288': {'SECCIONAMENTO': 'Coxipo',
#      'HORÁRIO CHEGADA': '2024-04-16 18:24:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-16 18:25:00'},
#     '0461': {'SECCIONAMENTO': 'Jaciara',
#      'HORÁRIO CHEGADA': '2024-04-16 20:15:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-16 20:45:00'},
#     '0350': {'SECCIONAMENTO': 'Rondonópolis',
#      'HORÁRIO CHEGADA': '2024-04-16 21:45:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 21:55:00'},
#     '0767': {'SECCIONAMENTO': 'Coxim',
#      'HORÁRIO CHEGADA': '2024-04-17 00:55:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 01:00:00'},
#     '1335': {'SECCIONAMENTO': 'Restaurante Talismã',
#      'HORÁRIO CHEGADA': '2024-04-17 01:05:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-17 01:25:00'},
#     '0772': {'SECCIONAMENTO': 'São Gabriel Do Oeste',
#      'HORÁRIO CHEGADA': '2024-04-17 02:59:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-17 03:00:00'},
#     '0771': {'SECCIONAMENTO': 'Campo Grande',
#      'HORÁRIO CHEGADA': '2024-04-17 05:05:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-17 05:20:00'},
#     '9277': {'SECCIONAMENTO': 'Campo Grande P. De Apoio',
#      'HORÁRIO CHEGADA': '2024-04-17 05:30:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-17 06:00:00'},
#     '0986': {'SECCIONAMENTO': 'Dourados P. De Apoio',
#      'HORÁRIO CHEGADA': '2024-04-17 09:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 09:10:00'},
#     '0726': {'SECCIONAMENTO': 'Dourados',
#      'HORÁRIO CHEGADA': '2024-04-17 09:15:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-17 09:25:00'},
#     '6553': {'SECCIONAMENTO': 'Dourados - Rest. Querencia',
#      'HORÁRIO CHEGADA': '2024-04-17 09:35:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-17 09:55:00'},
#     '0770': {'SECCIONAMENTO': 'Naviraí',
#      'HORÁRIO CHEGADA': '2024-04-17 12:00:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 12:05:00'},
#     '0774': {'SECCIONAMENTO': 'Eldorado',
#      'HORÁRIO CHEGADA': '2024-04-17 13:15:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-17 13:45:00'},
#     '0773': {'SECCIONAMENTO': 'Mundo Novo',
#      'HORÁRIO CHEGADA': '2024-04-17 14:15:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 14:20:00'},
#     '0314': {'SECCIONAMENTO': 'Guaíra',
#      'HORÁRIO CHEGADA': '2024-04-17 15:55:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 16:00:00'},
#     '4041': {'SECCIONAMENTO': 'Marechal C Rondon',
#      'HORÁRIO CHEGADA': '2024-04-17 17:00:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 17:05:00'},
#     '0218': {'SECCIONAMENTO': 'Toledo',
#      'HORÁRIO CHEGADA': '2024-04-17 17:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 17:55:00'},
#     '0208': {'SECCIONAMENTO': 'Cascavel',
#      'HORÁRIO CHEGADA': '2024-04-17 18:40:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-17 19:10:00'},
#     '1204': {'SECCIONAMENTO': 'Cascavel  Garagem',
#      'HORÁRIO CHEGADA': '2024-04-17 19:15:00',
#      'TEMPO DE PARADA': '01:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 20:15:00'}}}},
#  '00251': {'LINHA': 'Costa Marques x Cacoal',
#   'HORÁRIO INÍCIO': '08:02:00',
#   'PERCURSO': {'Volta': {'9423': {'SECCIONAMENTO': 'Km - 33',
#      'HORÁRIO CHEGADA': '09:27:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '09:27:00'}}}},
#  '00264': {'LINHA': 'Costa Marques x Cacoal',
#   'HORÁRIO INÍCIO': '08:02:00',
#   'PERCURSO': {'Volta': {'9256': {'SECCIONAMENTO': 'Santana Do Guapore',
#      'HORÁRIO CHEGADA': '12:57:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '13:02:00'}}}},
#  '00141': {'LINHA': 'Ji-Paraná x São Miguel Do Guaporé',
#   'HORÁRIO INÍCIO': '16:31:00',
#   'PERCURSO': {'Ida': {'0454': {'SECCIONAMENTO': 'Ji-Paraná - Garagem',
#      'HORÁRIO CHEGADA': '2024-04-17 15:46:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-17 16:01:00'},
#     '0962': {'SECCIONAMENTO': 'Ji-Paraná',
#      'HORÁRIO CHEGADA': '2024-04-17 16:16:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-17 16:31:00'},
#     '5016': {'SECCIONAMENTO': 'Km - 11',
#      'HORÁRIO CHEGADA': '2024-04-17 16:41:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 16:41:00'},
#     '5017': {'SECCIONAMENTO': 'Bandeira Branca',
#      'HORÁRIO CHEGADA': '2024-04-17 16:51:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 16:51:00'},
#     '0823': {'SECCIONAMENTO': 'Presidente Medici',
#      'HORÁRIO CHEGADA': '2024-04-17 17:16:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-17 17:26:00'},
#     '1153': {'SECCIONAMENTO': 'Presidente Medici 2',
#      'HORÁRIO CHEGADA': '2024-04-17 17:36:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 17:36:00'},
#     '5018': {'SECCIONAMENTO': 'Fazenda Muqui',
#      'HORÁRIO CHEGADA': '2024-04-17 17:51:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 17:51:00'},
#     '0205': {'SECCIONAMENTO': 'Igarape Grande',
#      'HORÁRIO CHEGADA': '2024-04-17 18:06:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 18:06:00'},
#     '5031': {'SECCIONAMENTO': 'Capa Zero',
#      'HORÁRIO CHEGADA': '2024-04-17 18:16:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 18:16:00'},
#     '5032': {'SECCIONAMENTO': 'Sítio Bom Jesus',
#      'HORÁRIO CHEGADA': '2024-04-17 18:21:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 18:21:00'},
#     '5033': {'SECCIONAMENTO': 'Igreja Católica',
#      'HORÁRIO CHEGADA': '2024-04-17 18:26:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 18:26:00'},
#     '5034': {'SECCIONAMENTO': 'Rolim De Moura',
#      'HORÁRIO CHEGADA': '2024-04-17 18:46:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-17 18:56:00'},
#     '0176': {'SECCIONAMENTO': 'Linha 176',
#      'HORÁRIO CHEGADA': '2024-04-17 19:00:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 19:00:00'},
#     '1135': {'SECCIONAMENTO': 'Linha 168',
#      'HORÁRIO CHEGADA': '2024-04-17 19:05:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 19:05:00'},
#     '0063': {'SECCIONAMENTO': 'Novo Horizonte',
#      'HORÁRIO CHEGADA': '2024-04-17 19:34:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 19:39:00'},
#     '0093': {'SECCIONAMENTO': 'Linha 152',
#      'HORÁRIO CHEGADA': '2024-04-17 19:48:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 19:48:00'},
#     '0232': {'SECCIONAMENTO': 'Migrantinópolis',
#      'HORÁRIO CHEGADA': '2024-04-17 19:58:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 20:03:00'},
#     '1233': {'SECCIONAMENTO': 'Linha 138',
#      'HORÁRIO CHEGADA': '2024-04-17 20:13:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 20:13:00'},
#     '0449': {'SECCIONAMENTO': 'Entrada Da Linha 25',
#      'HORÁRIO CHEGADA': '2024-04-17 20:18:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 20:18:00'},
#     '0475': {'SECCIONAMENTO': 'Nova Brasilândia',
#      'HORÁRIO CHEGADA': '2024-04-17 20:22:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 20:27:00'},
#     '0122': {'SECCIONAMENTO': 'Linha 114',
#      'HORÁRIO CHEGADA': '2024-04-17 20:31:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 20:31:00'},
#     '9256': {'SECCIONAMENTO': 'Santana Do Guapore',
#      'HORÁRIO CHEGADA': '2024-04-17 20:51:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-17 20:56:00'},
#     '0102': {'SECCIONAMENTO': 'Linha 102',
#      'HORÁRIO CHEGADA': '2024-04-17 21:01:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 21:01:00'},
#     '0094': {'SECCIONAMENTO': 'Linha 94',
#      'HORÁRIO CHEGADA': '2024-04-17 21:16:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 21:16:00'},
#     '1234': {'SECCIONAMENTO': 'Linha 90',
#      'HORÁRIO CHEGADA': '2024-04-17 21:21:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 21:21:00'},
#     '0403': {'SECCIONAMENTO': 'São Miguel Do Guaporé',
#      'HORÁRIO CHEGADA': '2024-04-17 21:31:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-17 21:41:00'},
#     '2054': {'SECCIONAMENTO': 'Sao Miguel -  Garagem',
#      'HORÁRIO CHEGADA': '2024-04-17 21:51:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-17 21:51:00'}},
#    'Volta': {'0403': {'SECCIONAMENTO': 'São Miguel Do Guaporé',
#      'HORÁRIO CHEGADA': '2024-04-15 09:00:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:15:00'},
#     '1234': {'SECCIONAMENTO': 'Linha 90',
#      'HORÁRIO CHEGADA': '2024-04-15 09:20:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:20:00'},
#     '0094': {'SECCIONAMENTO': 'Linha 94',
#      'HORÁRIO CHEGADA': '2024-04-15 09:25:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:25:00'},
#     '0102': {'SECCIONAMENTO': 'Linha 102',
#      'HORÁRIO CHEGADA': '2024-04-15 09:30:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:30:00'},
#     '9256': {'SECCIONAMENTO': 'Santana Do Guapore',
#      'HORÁRIO CHEGADA': '2024-04-15 09:40:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:40:00'},
#     '0221': {'SECCIONAMENTO': 'Linha-110',
#      'HORÁRIO CHEGADA': '2024-04-15 09:41:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:41:00'},
#     '0122': {'SECCIONAMENTO': 'Linha 114',
#      'HORÁRIO CHEGADA': '2024-04-15 09:45:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:45:00'},
#     '0475': {'SECCIONAMENTO': 'Nova Brasilândia',
#      'HORÁRIO CHEGADA': '2024-04-15 10:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:25:00'},
#     '0449': {'SECCIONAMENTO': 'Entrada Da Linha 25',
#      'HORÁRIO CHEGADA': '2024-04-15 10:30:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:30:00'},
#     '1233': {'SECCIONAMENTO': 'Linha 138',
#      'HORÁRIO CHEGADA': '2024-04-15 10:35:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:35:00'},
#     '0232': {'SECCIONAMENTO': 'Migrantinópolis',
#      'HORÁRIO CHEGADA': '2024-04-15 10:54:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:59:00'},
#     '0093': {'SECCIONAMENTO': 'Linha 152',
#      'HORÁRIO CHEGADA': '2024-04-15 11:04:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:04:00'},
#     '0063': {'SECCIONAMENTO': 'Novo Horizonte',
#      'HORÁRIO CHEGADA': '2024-04-15 11:23:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:28:00'},
#     '1135': {'SECCIONAMENTO': 'Linha 168',
#      'HORÁRIO CHEGADA': '2024-04-15 11:33:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:33:00'},
#     '0176': {'SECCIONAMENTO': 'Linha 176',
#      'HORÁRIO CHEGADA': '2024-04-15 11:38:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:38:00'},
#     '5034': {'SECCIONAMENTO': 'Rolim De Moura',
#      'HORÁRIO CHEGADA': '2024-04-15 12:01:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-15 12:31:00'},
#     '5033': {'SECCIONAMENTO': 'Igreja Católica',
#      'HORÁRIO CHEGADA': '2024-04-15 12:42:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 12:42:00'},
#     '5032': {'SECCIONAMENTO': 'Sítio Bom Jesus',
#      'HORÁRIO CHEGADA': '2024-04-15 12:52:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 12:52:00'},
#     '5031': {'SECCIONAMENTO': 'Capa Zero',
#      'HORÁRIO CHEGADA': '2024-04-15 12:57:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 12:57:00'},
#     '1631': {'SECCIONAMENTO': 'Linha-184',
#      'HORÁRIO CHEGADA': '2024-04-15 13:02:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 13:02:00'},
#     '0205': {'SECCIONAMENTO': 'Igarape Grande',
#      'HORÁRIO CHEGADA': '2024-04-15 13:12:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 13:12:00'},
#     '5018': {'SECCIONAMENTO': 'Fazenda Muqui',
#      'HORÁRIO CHEGADA': '2024-04-15 13:17:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 13:17:00'},
#     '1153': {'SECCIONAMENTO': 'Presidente Medici 2',
#      'HORÁRIO CHEGADA': '2024-04-15 13:31:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 13:31:00'},
#     '0823': {'SECCIONAMENTO': 'Presidente Medici',
#      'HORÁRIO CHEGADA': '2024-04-15 13:46:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 13:56:00'},
#     '5017': {'SECCIONAMENTO': 'Bandeira Branca',
#      'HORÁRIO CHEGADA': '2024-04-15 14:12:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 14:12:00'},
#     '5016': {'SECCIONAMENTO': 'Km - 11',
#      'HORÁRIO CHEGADA': '2024-04-15 14:22:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 14:22:00'},
#     '0962': {'SECCIONAMENTO': 'Ji-Paraná',
#      'HORÁRIO CHEGADA': '2024-04-15 14:46:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 14:51:00'},
#     '0454': {'SECCIONAMENTO': 'Ji-Paraná - Garagem',
#      'HORÁRIO CHEGADA': '2024-04-15 15:01:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 15:01:00'}}}},
#  '01500': {'LINHA': 'Porto Velho x Rio Branco',
#   'HORÁRIO INÍCIO': '09:45:00',
#   'PERCURSO': {'Ida': {'9075': {'SECCIONAMENTO': 'Porto Velho Garagem',
#      'HORÁRIO CHEGADA': '2024-04-16 09:05:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-16 09:05:00'},
#     '0234': {'SECCIONAMENTO': 'Porto Velho',
#      'HORÁRIO CHEGADA': '2024-04-16 09:15:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-16 09:45:00'},
#     '1040': {'SECCIONAMENTO': 'Jaci-Paraná',
#      'HORÁRIO CHEGADA': '2024-04-16 11:05:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-16 11:35:00'},
#     '0353': {'SECCIONAMENTO': 'Vila Nova Mutum',
#      'HORÁRIO CHEGADA': '2024-04-16 11:51:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 11:56:00'},
#     '0081': {'SECCIONAMENTO': 'Jirau',
#      'HORÁRIO CHEGADA': '2024-04-16 12:15:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-16 12:16:00'},
#     '2141': {'SECCIONAMENTO': 'Trevo Guajará Mirim',
#      'HORÁRIO CHEGADA': '2024-04-16 13:06:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 13:16:00'},
#     '1039': {'SECCIONAMENTO': 'Abunã',
#      'HORÁRIO CHEGADA': '2024-04-16 14:35:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 14:40:00'},
#     '2143': {'SECCIONAMENTO': 'Vista Alegre Do Abunã',
#      'HORÁRIO CHEGADA': '2024-04-16 15:05:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:15:00'},
#     '1212': {'SECCIONAMENTO': 'Extrema',
#      'HORÁRIO CHEGADA': '2024-04-16 15:20:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:30:00'},
#     '9811': {'SECCIONAMENTO': 'Nova Califórnia',
#      'HORÁRIO CHEGADA': '2024-04-16 15:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:50:00'},
#     '9624': {'SECCIONAMENTO': 'Posto Fiscal Tucandeira',
#      'HORÁRIO CHEGADA': '2024-04-16 15:20:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:21:00'},
#     '9856': {'SECCIONAMENTO': 'Trevo Acrelandia',
#      'HORÁRIO CHEGADA': '2024-04-16 15:40:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:50:00'},
#     '0325': {'SECCIONAMENTO': 'Vila Campinas',
#      'HORÁRIO CHEGADA': '2024-04-16 16:20:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-16 16:21:00'},
#     '0672': {'SECCIONAMENTO': 'Rio Branco',
#      'HORÁRIO CHEGADA': '2024-04-16 17:21:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 17:31:00'},
#     '6720': {'SECCIONAMENTO': 'Rio Branco Garagem',
#      'HORÁRIO CHEGADA': '2024-04-16 17:36:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-16 17:36:00'}},
#    'Volta': {'6720': {'SECCIONAMENTO': 'Rio Branco Garagem',
#      'HORÁRIO CHEGADA': '2024-04-16 09:25:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-16 09:25:00'},
#     '0672': {'SECCIONAMENTO': 'Rio Branco',
#      'HORÁRIO CHEGADA': '2024-04-16 09:30:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-16 10:00:00'},
#     '0325': {'SECCIONAMENTO': 'Vila Campinas',
#      'HORÁRIO CHEGADA': '2024-04-16 10:55:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-16 10:55:00'},
#     '9856': {'SECCIONAMENTO': 'Trevo Acrelandia',
#      'HORÁRIO CHEGADA': '2024-04-16 11:20:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 11:30:00'},
#     '9624': {'SECCIONAMENTO': 'Posto Fiscal Tucandeira',
#      'HORÁRIO CHEGADA': '2024-04-16 11:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 11:50:00'},
#     '9811': {'SECCIONAMENTO': 'Nova Califórnia',
#      'HORÁRIO CHEGADA': '2024-04-16 12:55:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 13:00:00'},
#     '1212': {'SECCIONAMENTO': 'Extrema',
#      'HORÁRIO CHEGADA': '2024-04-16 13:40:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-16 14:10:00'},
#     '2143': {'SECCIONAMENTO': 'Vista Alegre Do Abunã',
#      'HORÁRIO CHEGADA': '2024-04-16 15:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:10:00'},
#     '1039': {'SECCIONAMENTO': 'Abunã',
#      'HORÁRIO CHEGADA': '2024-04-16 15:44:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-16 15:45:00'},
#     '0353': {'SECCIONAMENTO': 'Vila Nova Mutum',
#      'HORÁRIO CHEGADA': '2024-04-16 17:29:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 17:34:00'},
#     '1040': {'SECCIONAMENTO': 'Jaci-Paraná',
#      'HORÁRIO CHEGADA': '2024-04-16 17:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-16 17:55:00'},
#     '0234': {'SECCIONAMENTO': 'Porto Velho',
#      'HORÁRIO CHEGADA': '2024-04-16 19:25:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-16 19:35:00'},
#     '9075': {'SECCIONAMENTO': 'Porto Velho Garagem',
#      'HORÁRIO CHEGADA': '2024-04-16 19:50:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-16 19:50:00'}}}},
#  '00272': {'LINHA': 'Costa Marques x Cacoal',
#   'HORÁRIO INÍCIO': '08:02:00',
#   'PERCURSO': {'Volta': {'1135': {'SECCIONAMENTO': 'Linha 168',
#      'HORÁRIO CHEGADA': '14:42:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '14:42:00'}}}},
#  '11162': {'LINHA': 'Aripuanã x Brasília',
#   'HORÁRIO INÍCIO': '11:00:00',
#   'PERCURSO': {'Ida': {'1560': {'SECCIONAMENTO': 'Aripuanã',
#      'HORÁRIO CHEGADA': '19:35:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '19:35:00'},
#     '0820': {'SECCIONAMENTO': 'Vilhena',
#      'HORÁRIO CHEGADA': '05:00:00',
#      'TEMPO DE PARADA': '00:50:00',
#      'HORÁRIO SAIDA': '05:50:00'},
#     '0474': {'SECCIONAMENTO': 'Comodoro',
#      'HORÁRIO CHEGADA': '07:15:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '07:25:00'},
#     '0348': {'SECCIONAMENTO': 'Pontes E Lacerda',
#      'HORÁRIO CHEGADA': '10:00:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '10:15:00'},
#     '0582': {'SECCIONAMENTO': 'Entroncamento Mirassol',
#      'HORÁRIO CHEGADA': '12:15:00',
#      'TEMPO DE PARADA': '00:40:00',
#      'HORÁRIO SAIDA': '12:55:00'},
#     '0349': {'SECCIONAMENTO': 'Cáceres',
#      'HORÁRIO CHEGADA': '14:05:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '14:25:00'},
#     '0346': {'SECCIONAMENTO': 'Cuiabá',
#      'HORÁRIO CHEGADA': '17:45:00',
#      'TEMPO DE PARADA': '01:00:00',
#      'HORÁRIO SAIDA': '18:45:00'},
#     '0461': {'SECCIONAMENTO': 'Jaciara',
#      'HORÁRIO CHEGADA': '20:55:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '21:25:00'},
#     '0350': {'SECCIONAMENTO': 'Rondonópolis',
#      'HORÁRIO CHEGADA': '22:25:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '22:40:00'},
#     '6014': {'SECCIONAMENTO': 'Alto Garças',
#      'HORÁRIO CHEGADA': '00:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '00:55:00'},
#     '0607': {'SECCIONAMENTO': 'Santa Rita Do Araguaia',
#      'HORÁRIO CHEGADA': '02:55:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '03:15:00'},
#     '0606': {'SECCIONAMENTO': 'Mineiros',
#      'HORÁRIO CHEGADA': '04:35:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '04:40:00'},
#     '9560': {'SECCIONAMENTO': 'Posto Sucal',
#      'HORÁRIO CHEGADA': '20:35:00',
#      'TEMPO DE PARADA': '00:40:00',
#      'HORÁRIO SAIDA': '21:15:00'},
#     '0605': {'SECCIONAMENTO': 'Jataí',
#      'HORÁRIO CHEGADA': '06:15:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '06:20:00'},
#     '0781': {'SECCIONAMENTO': 'Rio Verde',
#      'HORÁRIO CHEGADA': '08:10:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '08:15:00'},
#     '0190': {'SECCIONAMENTO': 'Goiânia',
#      'HORÁRIO CHEGADA': '11:35:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '11:50:00'},
#     '0436': {'SECCIONAMENTO': 'Anápolis',
#      'HORÁRIO CHEGADA': '03:24:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '03:25:00'},
#     '0613': {'SECCIONAMENTO': 'Brasília',
#      'HORÁRIO CHEGADA': '05:40:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '05:55:00'},
#     '2613': {'SECCIONAMENTO': 'Brasília - Garagem',
#      'HORÁRIO CHEGADA': '06:15:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '06:45:00'},
#     '2231': {'SECCIONAMENTO': 'Churrascaria Sucal',
#      'HORÁRIO CHEGADA': '06:25:00',
#      'TEMPO DE PARADA': '00:35:00',
#      'HORÁRIO SAIDA': '07:00:00'}},
#    'Volta': {'2613': {'SECCIONAMENTO': 'Brasília - Garagem',
#      'HORÁRIO CHEGADA': '12:00:00',
#      'TEMPO DE PARADA': '01:00:00',
#      'HORÁRIO SAIDA': '13:00:00'},
#     '0613': {'SECCIONAMENTO': 'Brasília',
#      'HORÁRIO CHEGADA': '13:45:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '14:00:00'},
#     '0436': {'SECCIONAMENTO': 'Anápolis',
#      'HORÁRIO CHEGADA': '16:15:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '16:25:00'},
#     '9621': {'SECCIONAMENTO': 'Posto Tiao Peixoto',
#      'HORÁRIO CHEGADA': '17:30:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '17:50:00'},
#     '0190': {'SECCIONAMENTO': 'Goiânia',
#      'HORÁRIO CHEGADA': '2024-04-22 17:40:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-22 18:00:00'},
#     '0967': {'SECCIONAMENTO': 'Rodoviaria De St. Campinas',
#      'HORÁRIO CHEGADA': '2024-04-22 18:25:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-22 18:30:00'},
#     '0965': {'SECCIONAMENTO': 'Restaurante America',
#      'HORÁRIO CHEGADA': '2024-04-22 19:25:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-22 19:55:00'},
#     '0781': {'SECCIONAMENTO': 'Rio Verde',
#      'HORÁRIO CHEGADA': '2024-04-22 22:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-22 22:25:00'},
#     '0605': {'SECCIONAMENTO': 'Jataí',
#      'HORÁRIO CHEGADA': '2024-04-22 23:35:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-22 23:40:00'},
#     '9560': {'SECCIONAMENTO': 'Posto Sucal',
#      'HORÁRIO CHEGADA': '2024-04-22 23:45:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-22 23:55:00'},
#     '0606': {'SECCIONAMENTO': 'Mineiros',
#      'HORÁRIO CHEGADA': '2024-04-23 01:15:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-23 01:20:00'},
#     '0607': {'SECCIONAMENTO': 'Santa Rita Do Araguaia',
#      'HORÁRIO CHEGADA': '2024-04-23 01:35:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-23 01:50:00'},
#     '6014': {'SECCIONAMENTO': 'Alto Garças',
#      'HORÁRIO CHEGADA': '2024-04-23 02:49:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-23 02:50:00'},
#     '0350': {'SECCIONAMENTO': 'Rondonópolis',
#      'HORÁRIO CHEGADA': '2024-04-23 04:50:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-23 05:20:00'},
#     '0461': {'SECCIONAMENTO': 'Jaciara',
#      'HORÁRIO CHEGADA': '2024-04-23 06:19:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-23 06:20:00'},
#     '0346': {'SECCIONAMENTO': 'Cuiabá',
#      'HORÁRIO CHEGADA': '2024-04-23 08:30:00',
#      'TEMPO DE PARADA': '00:45:00',
#      'HORÁRIO SAIDA': '2024-04-23 09:15:00'},
#     '0349': {'SECCIONAMENTO': 'Cáceres',
#      'HORÁRIO CHEGADA': '2024-04-23 12:15:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-23 12:20:00'},
#     '9693': {'SECCIONAMENTO': 'Restaurante Rio Paraguai',
#      'HORÁRIO CHEGADA': '2024-04-23 12:30:00',
#      'TEMPO DE PARADA': '00:40:00',
#      'HORÁRIO SAIDA': '2024-04-23 13:10:00'},
#     '0348': {'SECCIONAMENTO': 'Pontes E Lacerda',
#      'HORÁRIO CHEGADA': '2024-04-23 16:10:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-23 16:20:00'},
#     '0474': {'SECCIONAMENTO': 'Comodoro',
#      'HORÁRIO CHEGADA': '2024-04-23 19:00:00',
#      'TEMPO DE PARADA': '00:50:00',
#      'HORÁRIO SAIDA': '2024-04-23 19:50:00'},
#     '0820': {'SECCIONAMENTO': 'Vilhena',
#      'HORÁRIO CHEGADA': '2024-04-23 21:20:00',
#      'TEMPO DE PARADA': '00:50:00',
#      'HORÁRIO SAIDA': '2024-04-23 22:10:00'}}}},
#  '00070': {'LINHA': "Alta Floresta D'Oeste x Cacoal",
#   'HORÁRIO INÍCIO': '06:00:00',
#   'PERCURSO': {'Ida': {'0822': {'SECCIONAMENTO': 'Cacoal',
#      'HORÁRIO CHEGADA': '16:45:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '17:00:00'},
#     '5022': {'SECCIONAMENTO': 'Riozinho',
#      'HORÁRIO CHEGADA': '11:40:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '11:40:00'},
#     '0821': {'SECCIONAMENTO': 'Pimenta Bueno',
#      'HORÁRIO CHEGADA': '17:43:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '17:53:00'},
#     '0189': {'SECCIONAMENTO': 'Marreta',
#      'HORÁRIO CHEGADA': '12:29:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '12:29:00'},
#     '0245': {'SECCIONAMENTO': 'Capa - 24',
#      'HORÁRIO CHEGADA': '12:36:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '12:36:00'},
#     '0183': {'SECCIONAMENTO': 'Queixada',
#      'HORÁRIO CHEGADA': '12:43:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '12:43:00'},
#     '0247': {'SECCIONAMENTO': 'Araras - 2',
#      'HORÁRIO CHEGADA': '12:50:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '12:50:00'},
#     '0248': {'SECCIONAMENTO': 'Entrada  Abaitará',
#      'HORÁRIO CHEGADA': '12:57:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '12:57:00'},
#     '0222': {'SECCIONAMENTO': 'Nova Estrela',
#      'HORÁRIO CHEGADA': '18:30:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '18:35:00'},
#     '0303': {'SECCIONAMENTO': 'Bambu',
#      'HORÁRIO CHEGADA': '13:15:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:15:00'},
#     '0249': {'SECCIONAMENTO': 'Linha 192',
#      'HORÁRIO CHEGADA': '13:25:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:25:00'},
#     '5034': {'SECCIONAMENTO': 'Rolim De Moura',
#      'HORÁRIO CHEGADA': '18:54:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '19:04:00'},
#     '0166': {'SECCIONAMENTO': 'Serraria Paraná',
#      'HORÁRIO CHEGADA': '13:45:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:45:00'},
#     '0300': {'SECCIONAMENTO': 'Serraria Bambú',
#      'HORÁRIO CHEGADA': '13:50:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:50:00'},
#     '0003': {'SECCIONAMENTO': 'Santa Luzia',
#      'HORÁRIO CHEGADA': '19:29:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '19:34:00'},
#     '0169': {'SECCIONAMENTO': 'Linha 176/L. 54',
#      'HORÁRIO CHEGADA': '14:16:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '14:16:00'},
#     '0251': {'SECCIONAMENTO': 'Escolinha',
#      'HORÁRIO CHEGADA': '14:26:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '14:26:00'},
#     '0416': {'SECCIONAMENTO': "Alta Floresta D'Oeste",
#      'HORÁRIO CHEGADA': '20:04:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '20:14:00'},
#     '4160': {'SECCIONAMENTO': 'Alta Floresta - Garagem',
#      'HORÁRIO CHEGADA': '20:21:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '20:21:00'}},
#    'Volta': {'0416': {'SECCIONAMENTO': "Alta Floresta D'Oeste",
#      'HORÁRIO CHEGADA': '14:45:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '15:00:00'},
#     '0251': {'SECCIONAMENTO': 'Escolinha',
#      'HORÁRIO CHEGADA': '15:13:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '15:13:00'},
#     '0169': {'SECCIONAMENTO': 'Linha 176/L. 54',
#      'HORÁRIO CHEGADA': '15:23:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '15:23:00'},
#     '0003': {'SECCIONAMENTO': 'Santa Luzia',
#      'HORÁRIO CHEGADA': '15:30:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '15:35:00'},
#     '0300': {'SECCIONAMENTO': 'Serraria Bambú',
#      'HORÁRIO CHEGADA': '15:45:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '15:45:00'},
#     '0166': {'SECCIONAMENTO': 'Serraria Paraná',
#      'HORÁRIO CHEGADA': '15:50:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '15:50:00'},
#     '5034': {'SECCIONAMENTO': 'Rolim De Moura',
#      'HORÁRIO CHEGADA': '15:59:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '16:09:00'},
#     '0249': {'SECCIONAMENTO': 'Linha 192',
#      'HORÁRIO CHEGADA': '16:19:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:19:00'},
#     '0303': {'SECCIONAMENTO': 'Bambu',
#      'HORÁRIO CHEGADA': '16:24:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:24:00'},
#     '0222': {'SECCIONAMENTO': 'Nova Estrela',
#      'HORÁRIO CHEGADA': '16:34:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:34:00'},
# ...
#      'HORÁRIO CHEGADA': '13:15:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:15:00'},
#     '0245': {'SECCIONAMENTO': 'Capa - 24',
#      'HORÁRIO CHEGADA': '13:22:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:22:00'},
#     '0183': {'SECCIONAMENTO': 'Queixada',
#      'HORÁRIO CHEGADA': '13:29:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:29:00'},
#     '0247': {'SECCIONAMENTO': 'Araras - 2',
#      'HORÁRIO CHEGADA': '13:36:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:36:00'},
#     '0248': {'SECCIONAMENTO': 'Entrada  Abaitará',
#      'HORÁRIO CHEGADA': '13:43:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:43:00'},
#     '0222': {'SECCIONAMENTO': 'Nova Estrela',
#      'HORÁRIO CHEGADA': '13:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '13:50:00'},
#     '0303': {'SECCIONAMENTO': 'Bambu',
#      'HORÁRIO CHEGADA': '13:55:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '13:55:00'},
#     '0249': {'SECCIONAMENTO': 'Linha 192',
#      'HORÁRIO CHEGADA': '14:00:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '14:00:00'},
#     '5034': {'SECCIONAMENTO': 'Rolim De Moura',
#      'HORÁRIO CHEGADA': '14:25:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '14:35:00'},
#     '0176': {'SECCIONAMENTO': 'Linha 176',
#      'HORÁRIO CHEGADA': '14:37:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '14:37:00'},
#     '1135': {'SECCIONAMENTO': 'Linha 168',
#      'HORÁRIO CHEGADA': '14:47:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '14:47:00'},
#     '0063': {'SECCIONAMENTO': 'Novo Horizonte',
#      'HORÁRIO CHEGADA': '15:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '15:10:00'},
#     '0093': {'SECCIONAMENTO': 'Linha 152',
#      'HORÁRIO CHEGADA': '15:14:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '15:14:00'},
#     '0232': {'SECCIONAMENTO': 'Migrantinópolis',
#      'HORÁRIO CHEGADA': '15:30:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '15:35:00'},
#     '1233': {'SECCIONAMENTO': 'Linha 138',
#      'HORÁRIO CHEGADA': '15:49:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '15:49:00'},
#     '0449': {'SECCIONAMENTO': 'Entrada Da Linha 25',
#      'HORÁRIO CHEGADA': '15:59:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '15:59:00'},
#     '0475': {'SECCIONAMENTO': 'Nova Brasilândia',
#      'HORÁRIO CHEGADA': '16:00:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '16:10:00'},
#     '0122': {'SECCIONAMENTO': 'Linha 114',
#      'HORÁRIO CHEGADA': '16:14:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:14:00'},
#     '9256': {'SECCIONAMENTO': 'Santana Do Guapore',
#      'HORÁRIO CHEGADA': '16:20:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:20:00'},
#     '0102': {'SECCIONAMENTO': 'Linha 102',
#      'HORÁRIO CHEGADA': '16:33:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:33:00'},
#     '0094': {'SECCIONAMENTO': 'Linha 94',
#      'HORÁRIO CHEGADA': '16:43:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:43:00'},
#     '1234': {'SECCIONAMENTO': 'Linha 90',
#      'HORÁRIO CHEGADA': '16:53:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:53:00'},
#     '0403': {'SECCIONAMENTO': 'São Miguel Do Guaporé',
#      'HORÁRIO CHEGADA': '17:00:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '17:10:00'},
#     '0221': {'SECCIONAMENTO': 'Linha-110',
#      'HORÁRIO CHEGADA': '16:19:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '16:19:00'},
#     '0130': {'SECCIONAMENTO': 'Rio São Miguel',
#      'HORÁRIO CHEGADA': '17:12:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '17:12:00'},
#     '1185': {'SECCIONAMENTO': 'Linha 12',
#      'HORÁRIO CHEGADA': '17:22:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '17:22:00'},
#     '0131': {'SECCIONAMENTO': 'Seringueiras',
#      'HORÁRIO CHEGADA': '17:50:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '18:00:00'}},
#    'Volta': {'0403': {'SECCIONAMENTO': 'São Miguel Do Guaporé',
#      'HORÁRIO CHEGADA': '2024-04-15 07:50:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:00:00'},
#     '1234': {'SECCIONAMENTO': 'Linha 90',
#      'HORÁRIO CHEGADA': '2024-04-15 08:05:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:05:00'},
#     '0094': {'SECCIONAMENTO': 'Linha 94',
#      'HORÁRIO CHEGADA': '2024-04-15 08:15:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:15:00'},
#     '0102': {'SECCIONAMENTO': 'Linha 102',
#      'HORÁRIO CHEGADA': '2024-04-15 08:25:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:25:00'},
#     '9256': {'SECCIONAMENTO': 'Santana Do Guapore',
#      'HORÁRIO CHEGADA': '2024-04-15 08:38:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:38:00'},
#     '0221': {'SECCIONAMENTO': 'Linha-110',
#      'HORÁRIO CHEGADA': '2024-04-15 08:45:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:45:00'},
#     '0122': {'SECCIONAMENTO': 'Linha 114',
#      'HORÁRIO CHEGADA': '2024-04-15 08:46:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:46:00'},
#     '0475': {'SECCIONAMENTO': 'Nova Brasilândia',
#      'HORÁRIO CHEGADA': '2024-04-15 09:00:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:05:00'},
#     '0232': {'SECCIONAMENTO': 'Migrantinópolis',
#      'HORÁRIO CHEGADA': '2024-04-15 09:30:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:35:00'},
#     '0093': {'SECCIONAMENTO': 'Linha 152',
#      'HORÁRIO CHEGADA': '2024-04-15 09:45:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:45:00'},
#     '0063': {'SECCIONAMENTO': 'Novo Horizonte',
#      'HORÁRIO CHEGADA': '2024-04-15 09:55:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:00:00'},
#     '1135': {'SECCIONAMENTO': 'Linha 168',
#      'HORÁRIO CHEGADA': '2024-04-15 10:20:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:20:00'},
#     '0176': {'SECCIONAMENTO': 'Linha 176',
#      'HORÁRIO CHEGADA': '2024-04-15 10:30:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:30:00'},
#     '5034': {'SECCIONAMENTO': 'Rolim De Moura',
#      'HORÁRIO CHEGADA': '2024-04-15 10:35:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 10:45:00'},
#     '0249': {'SECCIONAMENTO': 'Linha 192',
#      'HORÁRIO CHEGADA': '2024-04-15 11:00:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:00:00'},
#     '0303': {'SECCIONAMENTO': 'Bambu',
#      'HORÁRIO CHEGADA': '2024-04-15 11:05:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:05:00'},
#     '0222': {'SECCIONAMENTO': 'Nova Estrela',
#      'HORÁRIO CHEGADA': '2024-04-15 11:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:25:00'},
#     '0248': {'SECCIONAMENTO': 'Entrada  Abaitará',
#      'HORÁRIO CHEGADA': '2024-04-15 11:30:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:30:00'},
#     '0247': {'SECCIONAMENTO': 'Araras - 2',
#      'HORÁRIO CHEGADA': '2024-04-15 11:37:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:37:00'},
#     '0183': {'SECCIONAMENTO': 'Queixada',
#      'HORÁRIO CHEGADA': '2024-04-15 11:44:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:44:00'},
#     '0245': {'SECCIONAMENTO': 'Capa - 24',
#      'HORÁRIO CHEGADA': '2024-04-15 11:51:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:51:00'},
#     '0189': {'SECCIONAMENTO': 'Marreta',
#      'HORÁRIO CHEGADA': '2024-04-15 11:58:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 11:58:00'},
#     '0821': {'SECCIONAMENTO': 'Pimenta Bueno',
#      'HORÁRIO CHEGADA': '2024-04-15 12:05:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 12:15:00'},
#     '5022': {'SECCIONAMENTO': 'Riozinho',
#      'HORÁRIO CHEGADA': '2024-04-15 12:50:00',
#      'TEMPO DE PARADA': '00:00:00',
#      'HORÁRIO SAIDA': '2024-04-15 12:50:00'},
#     '0822': {'SECCIONAMENTO': 'Cacoal',
#      'HORÁRIO CHEGADA': '2024-04-15 13:20:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 13:25:00'}}}},
#  '19900': {'LINHA': 'Campo Grande x Florianópolis',
#   'HORÁRIO INÍCIO': '07:00:00',
#   'PERCURSO': {'Ida': {'0241': {'SECCIONAMENTO': 'Florianópolis',
#      'HORÁRIO CHEGADA': '2024-04-14 19:10:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-14 19:30:00'},
#     '0242': {'SECCIONAMENTO': 'Balneário Camboriú',
#      'HORÁRIO CHEGADA': '2024-04-14 20:40:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-14 20:50:00'},
#     '0243': {'SECCIONAMENTO': 'Itajaí',
#      'HORÁRIO CHEGADA': '2024-04-14 21:10:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-14 21:15:00'},
#     '4129': {'SECCIONAMENTO': 'Barra Velha - Rodoviária',
#      'HORÁRIO CHEGADA': '2024-04-14 21:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-14 21:55:00'},
#     244.0: {'SECCIONAMENTO': 'Joinville',
#      'HORÁRIO CHEGADA': '2024-04-14 22:35:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-14 22:40:00'},
#     4129.0: {'SECCIONAMENTO': 'Barra Velha - Rodoviária',
#      'HORÁRIO CHEGADA': '2024-04-14 21:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-14 21:55:00'},
#     '0209': {'SECCIONAMENTO': 'Curitiba',
#      'HORÁRIO CHEGADA': '2024-04-15 01:05:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-15 01:25:00'},
#     '9517': {'SECCIONAMENTO': 'Curitiba - P. Apoio',
#      'HORÁRIO CHEGADA': '2024-04-15 01:55:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '2024-04-15 02:15:00'},
#     '0211': {'SECCIONAMENTO': 'Ponta Grossa',
#      'HORÁRIO CHEGADA': '2024-04-15 03:55:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 04:05:00'},
#     '9634': {'SECCIONAMENTO': 'Restaurante Soledade',
#      'HORÁRIO CHEGADA': '2024-04-15 05:30:00',
#      'TEMPO DE PARADA': '00:25:00',
#      'HORÁRIO SAIDA': '2024-04-15 05:55:00'},
#     '0212': {'SECCIONAMENTO': 'Apucarana',
#      'HORÁRIO CHEGADA': '2024-04-15 08:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 08:10:00'},
#     '0420': {'SECCIONAMENTO': 'Maringá',
#      'HORÁRIO CHEGADA': '2024-04-15 09:10:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 09:15:00'},
#     '0896': {'SECCIONAMENTO': 'Restaurante Cavalo Branco',
#      'HORÁRIO CHEGADA': '2024-04-15 12:05:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '2024-04-15 12:35:00'},
#     '0314': {'SECCIONAMENTO': 'Guaíra',
#      'HORÁRIO CHEGADA': '2024-04-15 14:05:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 14:15:00'},
#     '0773': {'SECCIONAMENTO': 'Mundo Novo',
#      'HORÁRIO CHEGADA': '2024-04-15 13:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 13:55:00'},
#     '0774': {'SECCIONAMENTO': 'Eldorado',
#      'HORÁRIO CHEGADA': '2024-04-15 14:25:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-15 14:40:00'},
#     '0990': {'SECCIONAMENTO': 'Itaquiraí',
#      'HORÁRIO CHEGADA': '2024-04-15 15:09:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-15 15:10:00'},
#     '0770': {'SECCIONAMENTO': 'Naviraí',
#      'HORÁRIO CHEGADA': '2024-04-15 15:50:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 15:55:00'},
#     '0987': {'SECCIONAMENTO': 'Caarapó - Juvenal',
#      'HORÁRIO CHEGADA': '2024-04-15 17:04:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '2024-04-15 17:05:00'},
#     '0726': {'SECCIONAMENTO': 'Dourados',
#      'HORÁRIO CHEGADA': '2024-04-15 17:55:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '2024-04-15 18:05:00'},
#     '0783': {'SECCIONAMENTO': 'Nova Alvorada Do Sul',
#      'HORÁRIO CHEGADA': '2024-04-15 19:40:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '2024-04-15 19:45:00'},
#     '0771': {'SECCIONAMENTO': 'Campo Grande',
#      'HORÁRIO CHEGADA': '2024-04-15 21:25:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '2024-04-15 21:40:00'}},
#    'Volta': {'0771': {'SECCIONAMENTO': 'Campo Grande',
#      'HORÁRIO CHEGADA': '06:45:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '07:00:00'},
#     '0783': {'SECCIONAMENTO': 'Nova Alvorada Do Sul',
#      'HORÁRIO CHEGADA': '08:40:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '08:45:00'},
#     '0726': {'SECCIONAMENTO': 'Dourados',
#      'HORÁRIO CHEGADA': '10:20:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '10:30:00'},
#     '6553': {'SECCIONAMENTO': 'Dourados - Rest. Querencia',
#      'HORÁRIO CHEGADA': '10:45:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '11:15:00'},
#     '0987': {'SECCIONAMENTO': 'Caarapó - Juvenal',
#      'HORÁRIO CHEGADA': '11:59:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '12:00:00'},
#     '0770': {'SECCIONAMENTO': 'Naviraí',
#      'HORÁRIO CHEGADA': '13:15:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '13:20:00'},
#     '0990': {'SECCIONAMENTO': 'Itaquiraí',
#      'HORÁRIO CHEGADA': '14:04:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '14:05:00'},
#     '0774': {'SECCIONAMENTO': 'Eldorado',
#      'HORÁRIO CHEGADA': '14:40:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '14:55:00'},
#     '0773': {'SECCIONAMENTO': 'Mundo Novo',
#      'HORÁRIO CHEGADA': '15:25:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '15:26:00'},
#     '0314': {'SECCIONAMENTO': 'Guaíra',
#      'HORÁRIO CHEGADA': '17:05:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '17:15:00'},
#     '0896': {'SECCIONAMENTO': 'Restaurante Cavalo Branco',
#      'HORÁRIO CHEGADA': '18:45:00',
#      'TEMPO DE PARADA': '00:30:00',
#      'HORÁRIO SAIDA': '19:15:00'},
#     '0420': {'SECCIONAMENTO': 'Maringá',
#      'HORÁRIO CHEGADA': '22:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '22:10:00'},
#     '0212': {'SECCIONAMENTO': 'Apucarana',
#      'HORÁRIO CHEGADA': '23:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '23:10:00'},
#     '9634': {'SECCIONAMENTO': 'Restaurante Soledade',
#      'HORÁRIO CHEGADA': '01:20:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '01:40:00'},
#     '0211': {'SECCIONAMENTO': 'Ponta Grossa',
#      'HORÁRIO CHEGADA': '03:05:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '03:10:00'},
#     '0209': {'SECCIONAMENTO': 'Curitiba',
#      'HORÁRIO CHEGADA': '04:55:00',
#      'TEMPO DE PARADA': '00:10:00',
#      'HORÁRIO SAIDA': '05:05:00'},
#     '1300': {'SECCIONAMENTO': 'Curitiba - Garagem',
#      'HORÁRIO CHEGADA': '05:30:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '05:50:00'},
#     '9555': {'SECCIONAMENTO': 'Restaurante Merlo',
#      'HORÁRIO CHEGADA': '07:20:00',
#      'TEMPO DE PARADA': '00:20:00',
#      'HORÁRIO SAIDA': '07:40:00'},
#     '0244': {'SECCIONAMENTO': 'Joinville',
#      'HORÁRIO CHEGADA': '08:09:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '08:10:00'},
#     '4129': {'SECCIONAMENTO': 'Barra Velha - Rodoviária',
#      'HORÁRIO CHEGADA': '08:49:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '08:50:00'},
#     '0243': {'SECCIONAMENTO': 'Itajaí',
#      'HORÁRIO CHEGADA': '09:24:00',
#      'TEMPO DE PARADA': '00:01:00',
#      'HORÁRIO SAIDA': '09:25:00'},
#     '0242': {'SECCIONAMENTO': 'Balneário Camboriú',
#      'HORÁRIO CHEGADA': '09:45:00',
#      'TEMPO DE PARADA': '00:05:00',
#      'HORÁRIO SAIDA': '09:50:00'},
#     '0241': {'SECCIONAMENTO': 'Florianópolis',
#      'HORÁRIO CHEGADA': '11:00:00',
#      'TEMPO DE PARADA': '00:15:00',
#      'HORÁRIO SAIDA': '11:15:00'}}}}}

# %%
display(planil)
# Out:
#      Projeto - Horários       Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 0             Cód Linha  Horário Inicial                 Linha   Cod Secc
# 1                   NaN              NaN                   NaN        NaN
# 2                 01034         13:00:00      Abonari x Manaus       0423
# 3                 01034         13:00:00      Abonari x Manaus       0941
# 4                 01034         13:00:00      Abonari x Manaus       0940
# ...                 ...              ...                   ...        ...
# 5344              01661         22:30:00  Vilhena x Rio Branco       0235
# 5345              01661         22:30:00  Vilhena x Rio Branco       0824
# 5346              01661         22:30:00  Vilhena x Rio Branco       0233
# 5347              01661         22:30:00  Vilhena x Rio Branco       0234
# 5348              01661         22:30:00  Vilhena x Rio Branco       0672
#
#                  Unnamed: 4                 Unnamed: 5             Unnamed: 6  \
# 0             Seccionamento  Horário\nChegada Prevista  Horário\nChegada Real
# 1                       NaN                        NaN                    NaN
# 2                   Abonari                   12:55:00                    NaN
# 3        Km 200 (Br 174) Am                   13:40:00                    NaN
# 4        Km 180 (Br 174) Am                   13:50:00                    NaN
# ...                     ...                        ...                    ...
# 5344  Ouro Preto Rodoviária        2024-04-20 04:55:00                    NaN
# 5345                   Jarú        2024-04-20 05:45:00                    NaN
# 5346              Ariquemes        2024-04-20 07:05:00                    NaN
# 5347            Porto Velho        2024-04-20 10:25:00                    NaN
# 5348             Rio Branco        2024-04-20 17:36:00                    NaN
#
#             Unnamed: 7     Unnamed: 8               Unnamed: 9  \
# 0     Parada\nPrevista  Parada\n Real  Horário\nSaída Prevista
# 1                  NaN            NaN                      NaN
# 2             00:05:00            NaN                 13:00:00
# 3             00:00:00            NaN                 13:40:00
# 4             00:00:00            NaN                 13:50:00
# ...                ...            ...                      ...
# 5344          00:10:00            NaN      2024-04-20 05:05:00
# 5345          00:10:00            NaN      2024-04-20 05:55:00
# 5346          00:15:00            NaN      2024-04-20 07:20:00
# 5347          00:50:00            NaN      2024-04-20 11:15:00
# 5348          00:10:00            NaN      2024-04-20 17:46:00
#
#                    Unnamed: 10          Unnamed: 11 Unnamed: 12  \
# 0     Horário\nSaída Realizado       Fuso \nHorário     Sentido
# 1                          NaN                  NaN         NaN
# 2                          NaN  1899-12-29 23:00:00       Volta
# 3                          NaN  1899-12-29 23:00:00       Volta
# 4                          NaN  1899-12-29 23:00:00       Volta
# ...                        ...                  ...         ...
# 5344                       NaN  1899-12-29 23:00:00         Ida
# 5345                       NaN  1899-12-29 23:00:00         Ida
# 5346                       NaN  1899-12-29 23:00:00         Ida
# 5347                       NaN  1899-12-29 23:00:00         Ida
# 5348                       NaN  1899-12-29 22:00:00         Ida
#
#              Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 0     Frequencia\nSemana         NaN         NaN         NaN         NaN
# 1                    Dom         Seg         Ter         Qua         Qui
# 2                      x         NaN         NaN         NaN         NaN
# 3                      x         NaN         NaN         NaN         NaN
# 4                      x         NaN         NaN         NaN         NaN
# ...                  ...         ...         ...         ...         ...
# 5344                   x           x         NaN         NaN         NaN
# 5345                   x           x         NaN         NaN         NaN
# 5346                   x           x         NaN         NaN         NaN
# 5347                   x           x         NaN         NaN         NaN
# 5348                   x           x         NaN         NaN         NaN
#
#      Unnamed: 18 Unnamed: 19
# 0            NaN         NaN
# 1            Sex         Sáb
# 2              x         NaN
# 3              x         NaN
# 4              x         NaN
# ...          ...         ...
# 5344           x         NaN
# 5345           x         NaN
# 5346           x         NaN
# 5347           x         NaN
# 5348           x         NaN
#
# [5349 rows x 20 columns]
